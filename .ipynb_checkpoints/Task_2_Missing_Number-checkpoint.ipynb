# %% [markdown]
# # Task 2: Missing Number
#
# From a function that has as a parameter a vector of positive integers of size 2^n -1, which is missing a number, this vector can be disordered, to search for the missing number from a quantum circuit.

# %% [markdown]
# ## Imports

# %%
import numpy as np
from missing_number import missing_number
from qiskit.visualization import plot_histogram
import random
import time

# %% [markdown]
# # Steps
#
# - Generate a list of size $2^n - 1$ and shuffle it.
# - Pop the last element of the list. This will be our missing number.
# - Run Grover's Algorithm to find the missing number.
#
# The `missing_number` function returns the missing number, the counts of the experiment and the quantum circuit.

# %%
# Choose a value of n 
n = 6

# Generate list of length 2^n and random shuffle it
x = np.arange(0,2**n)
random.shuffle(x)

# Pop the last element This will the missing number.
# Now the length of input vector is 2^n - 1
missing_num = x[-1]
x = x[:-1]

print("Input vector:")
print(x)

# Find the missing number
res, counts, circuit =  missing_number(x)

print("Acutal missing number:", missing_num)
print("Result returned by algorithm:", res)
# Out:
# Input vector:
# [33 21  6  8 38 32 35 12 62 18 23 47 54 16 19 63 59 10  3 52 36 57 34 56
#  22 60  9 28  1 45 30 46 48 29  2 14 40 41 17 15 11  0 49 42 39 61 50 20
#  13 24 51 25 27 26 37 31  7 43 53  5 44 58 55]
# Acutal missing number: 4
# Result returned by algorithm: 4

# %% [markdown]
# ## Visualization
#
# - We can print the quantum circuit used by the experiment.
# - We can display the counts obtained from the experiment and can also plot its corresponding histogram.

# %%
circuit.draw('mpl')

# %%
counts
# Out:
# {'101001': 1, '000010': 1, '000100': 1021, '010000': 1}

# %%
plot_histogram(counts)

# %% [markdown]
# ## Bonus:
#
# Which is the largest list that can be implemented? Identify it and describe the result
#
# We know that the Unitary matrix of the oracle, $U_f$ is of the order of $2^{n qubits}$ and n_qubits is equal to $n$. The number of elements in the $U_f$ is of the order $2^{2n}$. Since the size of float is 8 bytes in python, the number of bytes requried to store $U_f$ will be $8\times 2^{2n} = 2^{3 + 2n}$ bytes (1).
#
# I run this program on colab which has 16GB of RAM i.e. $16 \times 2^{30}= 2^{34}$ bytes (2). Solving (1) and (2) we get $n \approx 15$. This means that the largest list that can be implemented is of the size is nearly 15.
#
# We run the algorithm starting with $n = 2$ to $20$. We also print the time taken by the alogrithm to find the missing number.

# %%
for n in range(2,20):
    print("n:", n)
    
    # Generate list of length 2^n and random shuffle it
    x = np.arange(0,2**n)
    random.shuffle(x)

    # Pop the last element This will the missing number.
    # Now the length of input vector is 2^n - 1
    missing_num = x[-1]
    x = x[:-1]
    
    # Find the missing number
    start = time.time()
    res, _ , _ =  missing_number(x)
    end = time.time()
    
    # Check if the result is correct
    assert missing_num == res 
    
    print("Acutal missing number:", missing_num)
    print("Result returned by algorithm:", res)
    print("Time taken to find the missing number: {} s".format(np.round(end-start,4)))
    print('-'*50)

    # Delete variables and free up space
    del x, missing_num, start, end, res
# Out:
# n: 2
# Acutal missing number: 3
# Result returned by algorithm: 3
# Time taken to find the missing number: 0.0377 s
# --------------------------------------------------
# n: 3
# Acutal missing number: 1
# Result returned by algorithm: 1
# Time taken to find the missing number: 0.0854 s
# --------------------------------------------------
# n: 4
# Acutal missing number: 9
# Result returned by algorithm: 9
# Time taken to find the missing number: 0.1616 s
# --------------------------------------------------
# n: 5
# Acutal missing number: 6
# Result returned by algorithm: 6
# Time taken to find the missing number: 0.2368 s
# --------------------------------------------------
# n: 6
# Acutal missing number: 52
# Result returned by algorithm: 52
# Time taken to find the missing number: 0.4356 s
# --------------------------------------------------
# n: 7
# Acutal missing number: 35
# Result returned by algorithm: 35
# Time taken to find the missing number: 0.6829 s
# --------------------------------------------------
# n: 8
# Acutal missing number: 114
# Result returned by algorithm: 114
# Time taken to find the missing number: 1.2122 s
# --------------------------------------------------
# n: 9
# Acutal missing number: 218
# Result returned by algorithm: 218
# Time taken to find the missing number: 2.7146 s
# --------------------------------------------------
# n: 10
# Acutal missing number: 647
# Result returned by algorithm: 647
# Time taken to find the missing number: 12.493 s
# --------------------------------------------------
# n: 11
# Acutal missing number: 1479
# Result returned by algorithm: 1479
# Time taken to find the missing number: 103.446 s
# --------------------------------------------------
# n: 12

# %% [markdown]
# ### Explanation
#
# At `n=12` the system crashed. This happened because `n=12` requires $2^{12}$ states to simulate. The memory is filled by both, the unitary matrix and the simulation and therefore we ran out of memory.
#
# ### Solution
#
# Using GPUs is one solution as they can simulate very high number of qubits with less time. You can see how time grows exponentially from `n=10` to `n=12`.
#
# As of now, I am unable to use GPUs with qiskit and therefore created an [issue](https://github.com/Qiskit/qiskit-aer/issues/1609) in the qiskit-aer repository.
